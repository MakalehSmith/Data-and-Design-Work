# %% [markdown]
# Homework #2 Looking at Fast Food in the US

# %%
import pandas as pd

# %%
ff = pd.read_csv('data/FastFoodRestaurants.csv')

# %%
ff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# address       10000 non-null object
# city          10000 non-null object
# country       10000 non-null object
# keys          10000 non-null object
# latitude      10000 non-null float64
# longitude     10000 non-null float64
# name          10000 non-null object
# postalCode    10000 non-null object
# province      10000 non-null object
# websites      9535 non-null object
# dtypes: float64(2), object(8)
# memory usage: 781.3+ KB

# %%
ff['city']
# Out:
# 0                      Massena
# 1       Washington Court House
# 2                    Maysville
# 3                      Massena
# 4                       Athens
# 5                     Hamilton
# 6                    Englewood
# 7                       Saluda
# 8                    Batesburg
# 9                    Paragould
# 10                    Sheridan
# 11                  Monticello
# 12               Oklahoma City
# 13                   Lexington
# 14                   Tell City
# 15                  Louisville
# 16               Oklahoma City
# 17                      Leland
# 18                      Leland
# 19                   Brentwood
# 20                      Leland
# 21                 Hardinsburg
# 22               Wichita Falls
# 23          South Padre Island
# 24                       Miami
# 25                   Pineville
# 26                     Bastrop
# 27                   Claremore
# 28                     Minerva
# 29                 Leavenworth
# ...

# %%
ff[['city', 'name']]
# Out:
#                         city                         name
# 0                    Massena                   McDonald's
# 1     Washington Court House                      Wendy's
# 2                  Maysville             Frisch's Big Boy
# 3                    Massena                   McDonald's
# 4                     Athens              OMG! Rotisserie
# 5                   Hamilton               Domino's Pizza
# 6                  Englewood               Domino's Pizza
# 7                     Saluda                   McDonald's
# 8                  Batesburg                      Wendy's
# 9                  Paragould                    Pizza Hut
# 10                  Sheridan               SONIC Drive In
# 11                Monticello               Domino's Pizza
# 12             Oklahoma City                   McDonald's
# 13                 Lexington               Domino's Pizza
# 14                 Tell City           Long John Silver's
# ...

# %%
ff[['city','name']].describe()
# Out:
#               city        name
# count        10000       10000
# unique        2775         548
# top     Cincinnati  McDonald's
# freq           119        1886

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.bar('city','name')
# Out:
# <BarContainer object of 1 artists>

# %%
ff.groupby('name').count()
# Out:
#                               address  city  country  keys  latitude  \
# name
# 31st Avenue Gyro                    1     1        1     1         1
# 7-11                                1     1        1     1         1
# 7-Eleven                            1     1        1     1         1
# A & W Family Restaurant             1     1        1     1         1
# A&W                                 3     3        3     3         3
# A&W All American Food               3     3        3     3         3
# A&W All-American Food               4     4        4     4         4
# A&W All-American Foods              1     1        1     1         1
# A&W Restaurant                      3     3        3     3         3
# A&W/Long John Silvers               1     1        1     1         1
# A&w                                 1     1        1     1         1
# A&w Restaurant                      2     2        2     2         2
# ...

# %%
ff.groupby('name')['city'].count()
# Out:
# name
# 31st Avenue Gyro                  1
# 7-11                              1
# 7-Eleven                          1
# A & W Family Restaurant           1
# A&W                               3
# A&W All American Food             3
# A&W All-American Food             4
# A&W All-American Foods            1
# A&W Restaurant                    3
# A&W/Long John Silvers             1
# A&w                               1
# A&w Restaurant                    2
# AJ's Hotdogs & Gyros              1
# Alice's                           1
# Ama Ristorante                    1
# Amigos/Kings Classic              5
# Aprisa Mexican Cuisine            1
# Arby's                          518
# Arby's Antigo                     1
# Arbys                             2
# Arctic Circle                     6
# Au Bon Pain                       2
# Auntie Anne's                     3
# Aw Restaurant                     1
# B K                               1
# B Z Breakfast Burgers Beyond      1
# ...

# %%
nc = ff.groupby('name')['city'].count()

# %%
nc.index
# Out:
# Index(['31st Avenue Gyro', '7-11', '7-Eleven', 'A & W Family Restaurant',
#        'A&W', 'A&W All American Food', 'A&W All-American Food',
#        'A&W All-American Foods', 'A&W Restaurant', 'A&W/Long John Silvers',
#        ...
#        'World Wrapps', 'Wu's Fine Chinese Cuisine', 'Yellow Cab Pizza Co.',
#        'Yoshinoya', 'Your Healthy Habit', 'Yum Brands Inc', 'Zaxby's',
#        'Zip's Hamburgers And Fish', 'Ziti's Italian Express', 'b.good'],
#       dtype='object', name='name', length=548)

# %%
# Out:
# <BarContainer object of 548 artists>

# %%
ff.groupby('name')['postalCode'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ecfb9bb99925> in <module>()
# ----> 1 ff.groupby('name')['postalCode'].count()
#
# NameError: name 'ff' is not defined
